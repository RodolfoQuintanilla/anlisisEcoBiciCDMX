# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # EDA

# %%
#1. Cargar los Datos

df = pd.read_csv('../data/processed/eco_bici_limpio.csv')

# %%
#2. Dimenciones del DataFrame
df.head()
# Out:
#   genero_usuario  edad_usuario     bici  ciclo_estacion_retiro fecha_retiro  \
# 0              M          26.0  5180930                    568   31/12/2024
# 1              F          54.0  3653953                    283   31/12/2024
# 2              M          38.0  7511322                     34   31/12/2024
# 3              M          41.0  3804572                    258   31/12/2024
# 4              M          35.0  3848405                     43   31/12/2024
#
#            hora_retiro  ciclo_estacionarribo fecha_arribo  \
# 0  1900-01-01 23:57:02                   572   01/01/2025
# 1  1900-01-01 23:51:40                   596   01/01/2025
# 2  1900-01-01 23:48:36                    64   01/01/2025
# 3  1900-01-01 23:54:11                    23   01/01/2025
# 4  1900-01-01 23:35:28                   126   01/01/2025
#
#            hora_arribo              fecha
# 0  1900-01-01 00:00:03  -1 days +00:03:01
# 1  1900-01-01 00:00:41  -1 days +00:09:01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22907263 entries, 0 to 22907262
# Data columns (total 10 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   genero_usuario         object
#  1   edad_usuario           float64
#  2   bici                   int64
#  3   ciclo_estacion_retiro  int64
#  4   fecha_retiro           object
#  5   hora_retiro            object
#  6   ciclo_estacionarribo   int64
#  7   fecha_arribo           object
#  8   hora_arribo            object
#  9   fecha                  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.7+ GB

# %%
df.columns
# Out:
# Index(['genero_usuario', 'edad_usuario', 'bici', 'ciclo_estacion_retiro',
#        'fecha_retiro', 'hora_retiro', 'ciclo_estacionarribo', 'fecha_arribo',
#        'hora_arribo', 'fecha'],
#       dtype='object')

# %%
print(f"Numero de Registros: {df.shape}")
# Out:
# Numero de Registros (22907263, 10)

# %%
#3. Analisis descriptivo
df.describe()
# Out:
#        edad_usuario          bici  ciclo_estacion_retiro  ciclo_estacionarribo
# count  2.290726e+07  2.290726e+07           2.290726e+07          2.290726e+07
# mean   3.424789e+01  5.465407e+06           2.952827e+02          2.919970e+02
# std    9.827688e+00  2.023987e+06           2.120570e+02          2.134173e+02
# min    1.600000e+01  2.000461e+06           1.000000e+00          1.000000e+00
# 25%    2.700000e+01  3.733581e+06           1.060000e+02          9.700000e+01
# 50%    3.200000e+01  5.472956e+06           2.550000e+02          2.490000e+02
# 75%    3.900000e+01  7.213606e+06           4.890000e+02          4.900000e+02
# max    1.430000e+02  8.999708e+06           1.000000e+03          1.000000e+03

# %%
df["fecha_arribo"] = pd.to_datetime(df["fecha_arribo"], format='%d/%m/%Y', errors='coerce')
df["fecha_retiro"] = pd.to_datetime(df["fecha_retiro"], format='%d/%m/%Y', errors='coerce')

# %%
df["hora_retiro"] = pd.to_datetime(df["hora_retiro"], format='%d/%m/%Y', errors='coerce')
df["hora_retiro"].dt.hour

# %%
#4. Visualizacion de los Datos

plt.figure(figsize=(10,8))
df.boxplot()
plt.show()

# %%
#Limpieza y preparacion de Datos
df_new = df.copy()

# %%
print("Numero de Duplicados")
df_new.isnull().sum()
# Out:
# genero_usuario           0
# edad_usuario             0
# bici                     0
# ciclo_estacion_retiro    0
# fecha_retiro             0
# hora_retiro              0
# ciclo_estacionarribo     0
# fecha_arribo             0
# hora_arribo              0
# fecha                    0
# dtype: int64

# %%
duplicado = df_new.duplicated().sum()
print(f"Datos de Duplicados: {duplicado}")
# Out:
# Numero de Duplicados: 0

# %%
#6. Datos faltantes
nans= df.isna().sum()
print(f"Datos is NaN: {nans}")
# Out:
# Datos is NaN: genero_usuario           0
# edad_usuario             0
# bici                     0
# ciclo_estacion_retiro    0
# fecha_retiro             0
# hora_retiro              0
# ciclo_estacionarribo     0
# fecha_arribo             0
# hora_arribo              0
# fecha                    0
# dtype: int64

# %%
#7. Valores atipicos
plt.figure(figsize=(10,6))
sns.boxplot(data=df)
plt.show()
