# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Inicio de Analisis EDA

# %%
# 1. Cargar los datos
df = pd.read_csv("../../data/processed/eco_bici_cdmx.csv")
